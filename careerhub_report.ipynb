# %%
import heapq
import string
from collections import Counter
import nltk
import pandas as pd
from nltk.corpus import stopwords
from nltk.stem import PorterStemmer

# %%
# data cleaning function
def process_words(raw, remove_punc=False, add_stopwords=False, stem=False):
    raw = str(raw).lower()
    if remove_punc:
        nopunc = [c for c in raw if c not in string.punctuation]
        raw = ''.join(nopunc)

    stopwords_list = []
    stopwords_list_en = set(stopwords.words('english'))
    stopwords_list_fr = set(stopwords.words('french'))
    stopwords_list.extend(stopwords_list_en)
    stopwords_list.extend(stopwords_list_fr)
    if add_stopwords:
        stopwords_list.extend(additional_stopwords())
    nostop = [w for w in raw.split() if w.lower() not in stopwords_list]
    if stem:
        stemmer = PorterStemmer()
        return ' '.join([stemmer.stem(t) for t in nostop])
    else:
        return ' '.join(nostop)

# apply additional stopwords to the default nltk ones
def additional_stopwords():
    stopwords_file = open('additional_stopwords.txt')
    return [w.lower().replace('\n', '') for w in stopwords_file.readlines()]


def word_weight(s):
    fdist = nltk.FreqDist(s.split())
    fdict = dict(fdist)
    wdict = {}
    for key in fdict.keys():
        wdict[key] = fdict[key] / max(fdict.values())
    return wdict


def sentence_score(sentences, word_weight_dict: dict):
    sent_score = {}
    for sentence in sentences:
        for word in nltk.word_tokenize(sentence):
            if word in word_weight_dict.keys():
                if sentence not in sent_score.keys():
                    sent_score[sentence] = word_weight_dict[word]
                else:
                    sent_score[sentence] += word_weight_dict[word]
    return sent_score


def top_words(s):
    words_list = s.split()
    counter = Counter(words_list)
    most_tuple = counter.most_common(10)
    most_list = [e[0] for e in most_tuple]
    return most_list

# %%
df = pd.read_json('data.json')
df.dropna(subset=['descr'], inplace=True)
df['descr_no_punc'] = df['descr'].apply(lambda x: process_words(x, remove_punc=True))
df['descr_sent_token'] = df['descr'].apply(lambda x: nltk.sent_tokenize(process_words(x)))
df['descr_word_wt'] = df['descr_no_punc'].apply(lambda x: word_weight(x))
df['descr_sent_score'] = df.apply(lambda df: sentence_score(df['descr_sent_token'], df['descr_word_wt']), axis=1)
df['descr_summ'] = df['descr_sent_score'].apply(lambda d: heapq.nlargest(3, d, key=d.get))
df['descr_add_stopword'] = df['descr'].apply(lambda x: process_words(x, remove_punc=True, add_stopwords=True))
df['descr_top_words'] = df['descr_add_stopword'].apply(lambda x:top_words(x))

result = df[['title','company','descr_top_words','descr_summ','link']]

# %%
result
# Out:
#                                                 title  \
# 0                                   Solutions Analyst
# 2                              Analyst, Public Credit
# 6                         Analyst, Advanced Analytics
# 7                             Senior   Data Analytics
# 9                                Software Engineer II
# 10  Senior Analyst, Workflow Optimization & Analytics
# 11                        Senior Quantitative Analyst
# 12              Senior Specialist, Process Innovation
# 13              Senior Specialist, Process Innovation
# 14                               Software Engineer II
# 15                               Software Engineer II
# 17              Senior Specialist, Process Innovation
# 19              Senior Specialist, Process Innovation
# 20           Manager Counterparty Credit Risk Capital
# 22            Capital Markets Analytics   VP/Director
# 23   Director, Performance and Analytics, MRM//McCann
# 24                Analyste, titres de cr ance publics
# 25  Manager, Workflow Analytics & Insights (Pharmacy)
# 27                           Senior Actuarial Analyst
# 29                             Senior Pricing Actuary
# 30                Data Scientist / Sr. Data Scientist
# 31                     Manager, Credit Risk Analytics
# 32                                                MES
# 33              Senior Specialist, Process Innovation
# 36                         Senior Credit Risk Analyst
# 37                               Software Engineer II
# 38                        Senior Financial Analyst II
# 40                       Manager   Business Modelling
# 42                     Senior Financial Analyst, FP&A
# 43  Senior Analyst - Fixed Income, Currencies, and...
# 44     Manager, Internal Capital and Credit Analytics
# 45                  AVP, Portfolio and Risk Analytics
# 46                         Director and Actuary, GVAH
# 47                               Software Engineer II
# 48                        Senior   Business Modelling
#
#                            company  \
# 0                       GS1 Canada
# 2             CPP Investment Board
# 6     President's Choice Financial
# 7                               EY
# 9                       LoyaltyOne
# 10              Shoppers Drug Mart
# 11                        Manulife
# 12             Samsung Electronics
# 13             Samsung Electronics
# 14                      LoyaltyOne
# 15                      LoyaltyOne
# 17             Samsung Electronics
# 19             Samsung Electronics
# 20             BMO Financial Group
# 22             BMO Financial Group
# 23          Worldgroup Careers MWT
# 24            CPP Investment Board
# 25              Shoppers Drug Mart
# 27                             RGA
# 29          Everest Re Group, Ltd.
# 30                        Manulife
# 31                      Scotiabank
# 32     Grantek Systems Integration
# 33             Samsung Electronics
# 36           Rogers Communications
# 37                      LoyaltyOne
# 38                         Staples
# 40                              EY
# 42  The Finance Department Limited
# 43             BMO Financial Group
# 44                      Scotiabank
# 45                        Manulife
# 46                        Manulife
# 47                      LoyaltyOne
# 48                              EY
#
#                                       descr_top_words  \
# 0   [industry, analyst, vendor, various, informati...
# 2   [portfolio, monitoring, credit, responsible, p...
# 6   [lcl, data, choice, pcf, insurance, analysis, ...
# 7   [analytics, data, decision, analytical, modell...
# 9   [data, loyalty, marketing, solutions, reports,...
# 10  [data, drug, shoppers, mart, workflow, modelin...
# 11  [quantitative, customers, modelling, model, an...
# 12  [process, projects, samsung, scm, operational,...
# 13  [process, projects, samsung, scm, operational,...
# 14  [data, loyalty, marketing, solutions, reports,...
# 15  [data, loyalty, marketing, solutions, reports,...
# 17  [process, projects, samsung, scm, operational,...
# 19  [process, projects, samsung, scm, operational,...
# 20  [capital, test, testing, credit, data, custome...
# 22  [customers, office, pricing, bmo, impact, anal...
# 23  [analytics, marketing, data, strategic, media,...
# 24  [portefeuille, risques, surveillance, cr, stra...
# 25  [pharmacy, data, reporting, drug, analytical, ...
# 27  [data, analysis, collateral, valuation, life, ...
# 29  [pricing, status, everest, insurance, group, r...
# 30  [data, analysis, customers, analytics, advance...
# 31  [ecl, process, credit, production, internal, i...
# 32  [solutions, platforms, microsoft, grantek, eng...
# 33  [process, projects, samsung, scm, operational,...
# 36  [credit, rogers, us, loss, statistical, reach,...
# 37  [data, loyalty, marketing, solutions, reports,...
# 38  [staples, data, analysis, supply, chain, drive...
# 40  [modelling, decisions, strategic, clients, vme...
# 42  [accounting, industry, cma, ca, mba, cfa, tfdl...
# 43  [pl, areas, profit, reporting, trading, partne...
# 44  [capital, credit, analytics, internal, bank, r...
# 45  [derivatives, derivative, curves, hedge, testi...
# 46  [hedging, va, actuarial, modelling, develop, c...
# 47  [data, loyalty, marketing, solutions, reports,...
# 48  [modelling, part, transaction, would, talented...
#
#                                            descr_summ  \
# 0   [subscriber feedback, business requirements, s...
# 2   [also assist hedging portfolio risks, includin...
# 6   [pcf vision provide superior value financial p...
# 7   [decision making environment requires strong c...
# 9   [description:why work us passionate data repor...
# 10  [evaluate business hypothesesevaluate accuracy...
# 11  [).responsibilitiesdevelop models generate eco...
# 12  [position key liaison sales & marketing, scm, ...
# 13  [position key liaison sales & marketing, scm, ...
# 14  [description:why work us passionate data repor...
# 15  [description:why work us passionate data repor...
# 17  [position key liaison sales & marketing, scm, ...
# 19  [position key liaison sales & marketing, scm, ...
# 20  [write business requirementsupport implementat...
# 22  [).aggregating, organizing analyzing market tr...
# 23  [critical individual passion credibility withi...
# 24  [les principales responsabilit comprennent : l...
# 25  [successful candidate play major role enhancin...
# 27  [sr. actuarial analyst contribute development ...
# 29  [line businesses include gl, umbrella, inland ...
# 30  [ability communicate results educate others re...
# 31  [manage timely resolution audit regulatory iss...
# 32  [multi-site rollouts commonplace, grantek clie...
# 33  [position key liaison sales & marketing, scm, ...
# 36  [sports fan celebrate special moment.because b...
# 37  [work us passionate data reporting?as part mem...
# 38  [identify explain variances regular basis.perf...
# 40  [team advisors sits heart global valuation, mo...
# 42  [advancement opportunities available individua...
# 43  [broad mandate includes: profit & loss profit ...
# 44  [previous experience moody's analytics risk fr...
# 45  [due breadth, role requires collaboration acro...
# 46  [opportunities gain exposure topical emerging ...
# 47  [description:why work us passionate data repor...
# 48  [part role would work varied portfolio busines...
#
#                                                  link
# 0   https://www.indeed.ca/viewjob?jk=72f855ddc32d6...
# 2   https://www.indeed.ca/viewjob?jk=799477c5840d0...
# 6   https://ca.indeed.com/viewjob?jk=7407746bfc7d1...
# 7   https://ca.indeed.com/viewjob?jk=713ba3c8f3ed5...
# 9   https://ca.indeed.com/viewjob?jk=868b0b6f130af...
# 10  https://ca.indeed.com/viewjob?jk=4d4ad6339c275...
# 11  https://ca.indeed.com/viewjob?jk=b185978f274dc...
# 12  https://ca.indeed.com/viewjob?jk=4e4071e621227...
# 13  https://ca.indeed.com/viewjob?jk=4e4071e621227...
# 14  https://ca.indeed.com/viewjob?jk=868b0b6f130af...
# 15  https://ca.indeed.com/viewjob?jk=868b0b6f130af...
# 17  https://ca.indeed.com/viewjob?jk=4e4071e621227...
# 19  https://ca.indeed.com/viewjob?jk=4e4071e621227...
# 20  https://ca.indeed.com/viewjob?jk=5c8f35df4cae5...
# 22  https://ca.indeed.com/viewjob?jk=a8c90d07d90ac...
# 23  https://www.indeed.ca/viewjob?jk=f96b18ffca6a1...
# 24  https://www.indeed.ca/viewjob?jk=8fb4be4af59e1...
# 25  https://ca.indeed.com/viewjob?jk=d6b9d15bea1b5...
# 27  https://www.indeed.ca/viewjob?jk=f9d3734e82329...
# 29  https://ca.indeed.com/viewjob?jk=8459a9bd1bc8b...
# 30  https://ca.indeed.com/viewjob?jk=e5ec98e98da8a...
# 31  https://ca.indeed.com/viewjob?jk=278a61358232a...
# 32  https://ca.indeed.com/viewjob?jk=fd44a815806ef...
# 33  https://ca.indeed.com/viewjob?jk=4e4071e621227...
# 36  https://ca.indeed.com/viewjob?jk=9d8afe5070e30...
# 37  https://ca.indeed.com/viewjob?jk=1d23c7d2e7278...
# 38  https://ca.indeed.com/viewjob?jk=9909afe694227...
# 40  https://ca.indeed.com/viewjob?jk=865ba9c7d6a7a...
# 42  https://ca.indeed.com/viewjob?jk=9d96fcaca43a2...
# 43  https://ca.indeed.com/viewjob?jk=8beae170860b6...
# 44  https://ca.indeed.com/viewjob?jk=77c78b76bf026...
# 45  https://ca.indeed.com/viewjob?jk=2ba6b8987074b...
# 46  https://ca.indeed.com/viewjob?jk=0946170a9f240...
# 47  https://ca.indeed.com/viewjob?jk=868b0b6f130af...
# 48  https://ca.indeed.com/viewjob?jk=9bbf2fd8be7a7...
